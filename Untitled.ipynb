# %%
import seaborn as sns

# %%
import pandas as pd

# %%
runs = pd.read_csv("./artifacts/n_instances/run.csv")

# %%
runs
# Out:
#     n_instances  best_train_runtime  predicted_test_runtime  \
# 0             3            0.018339                0.035726
# 1             4            0.011953                0.045859
# 2             5            0.023887                0.026263
# 3             6            0.015716                0.025187
# 4             7            0.023268                0.206418
# 5             8            0.026488                0.054547
# 6             9            0.018843                0.088705
# 7            10            0.023689                0.026905
# 8            11            0.021301                0.067412
# 9            12            0.021562                0.076614
# 10           13            0.020934                0.024316
# 11           14            0.018833                0.024563
# 12           15            0.024264                0.018395
# 13           16            0.016219                0.055956
# 14           17            0.018253                0.049085
# ...

# %% [markdown]
# ### Question 1

# %%
sns.lineplot(runs[["default_test_runtime", "predicted_test_runtime"]])
# Out:
# <Axes: >

# %%
import datetime

# %%
round(datetime.datetime.now().timestamp())
# Out:
# 1697050351
